# %% [markdown]
# List of different recommendations:
# 1) Profitability: What types movies have been the most profitable worldwide? ie; gross/costs
#
# 2) Exceptionalism: What types movies have been the highest rated? ie; ratings
#
# 3) Timing: When in the year have the most profitable movies been released?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1) Profitability
# What types of movies have been the most profitable worldwide?

# %%
df1 = pd.read_csv("C:/Users/User/Documents/Phase_1/tn.movie_budgets.csv.gz")
df2 = pd.read_csv("C:/Users/User/Documents/Phase_1/imdb.title.basics.csv.gz")

# %%
df1.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
df3 = df1.reset_index()

# %%
df4 = df2.reset_index()

# %%
df3.columns
# Out:
# Index(['index', 'id', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['index', 'tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
combined_df = df3.merge(df4, left_on='movie', right_on='primary_title', how='inner')
combined_df
# Out:
#       index_x  id  release_date                                        movie  \
# 0           0   1  Dec 18, 2009                                       Avatar
# 1           1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2           2   3   Jun 7, 2019                                 Dark Phoenix
# 3           3   4   May 1, 2015                      Avengers: Age of Ultron
# 4           6   7  Apr 27, 2018                       Avengers: Infinity War
# ...       ...  ..           ...                                          ...
# 3810     5767  68   Jul 6, 2001                                         Cure
# 3811     5769  70   Apr 1, 1996                                         Bang
# 3812     5772  73  Jan 13, 2012                                    Newlyweds
# 3813     5777  78  Dec 31, 2018                                       Red 11
# 3814     5780  81  Sep 29, 2015                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross  index_y     tconst  \
# 0         $425,000,000   $760,507,625  $2,776,345,279    17060  tt1775309
# 1         $410,600,000   $241,063,875  $1,045,663,875     6448  tt1298650
# 2         $350,000,000    $42,762,350    $149,762,350   112147  tt6565702
# 3         $330,600,000   $459,005,868  $1,403,013,963    39010  tt2395427
# 4         $300,000,000   $678,815,482  $2,048,134,200    72820  tt4154756
# ...                ...            ...             ...      ...        ...
# 3810           $10,000        $94,596         $94,596   101589  tt5936960
# 3811           $10,000           $527            $527   112781  tt6616538
# 3812            $9,000         $4,584          $4,584    21418  tt1880418
# 3813            $7,000             $0              $0   127755  tt7837402
# 3814            $1,400             $0              $0    28674  tt2107644
#
#                                     primary_title  \
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# 3                         Avengers: Age of Ultron
# 4                          Avengers: Infinity War
# ...                                           ...
# 3810                                         Cure
# 3811                                         Bang
# 3812                                    Newlyweds
# 3813                                       Red 11
# 3814                         A Plague So Pleasant
#
#                                    original_title  start_year  \
# 0                                           Abatâ        2011
# 1     Pirates of the Caribbean: On Stranger Tides        2011
# 2                                    Dark Phoenix        2019
# 3                         Avengers: Age of Ultron        2015
# 4                          Avengers: Infinity War        2018
# ...                                           ...         ...
# 3810                                         Cure        2014
# 3811                                         Bang        2015
# 3812                                    Newlyweds        2011
# 3813                                       Red 11        2019
# 3814                         A Plague So Pleasant        2013
#
#       runtime_minutes                    genres
# 0                93.0                    Horror
# 1               136.0  Action,Adventure,Fantasy
# 2               113.0   Action,Adventure,Sci-Fi
# 3               141.0   Action,Adventure,Sci-Fi
# 4               149.0   Action,Adventure,Sci-Fi
# ...               ...                       ...
# 3810              NaN                       NaN
# 3811              NaN                       NaN
# 3812             95.0              Comedy,Drama
# 3813             77.0    Horror,Sci-Fi,Thriller
# 3814             76.0     Drama,Horror,Thriller
#
# [3815 rows x 14 columns]

# %%
combined_df.dropna(inplace=True)
newcombined_df = combined_df['genres'].str.split(",", n=2, expand=True)
combined_df['genre 1']=newcombined_df[0]
combined_df['genre 2']=newcombined_df[1]
combined_df['genre 3']=newcombined_df[2]
combined_df.drop(columns = ['genres'], inplace = True)
combined_df
# Out:
#       index_x  id  release_date                                        movie  \
# 0           0   1  Dec 18, 2009                                       Avatar
# 1           1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2           2   3   Jun 7, 2019                                 Dark Phoenix
# 3           3   4   May 1, 2015                      Avengers: Age of Ultron
# 4           6   7  Apr 27, 2018                       Avengers: Infinity War
# ...       ...  ..           ...                                          ...
# 3808     5766  67  Apr 28, 2006                                        Clean
# 3809     5767  68   Jul 6, 2001                                         Cure
# 3812     5772  73  Jan 13, 2012                                    Newlyweds
# 3813     5777  78  Dec 31, 2018                                       Red 11
# 3814     5780  81  Sep 29, 2015                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross  index_y     tconst  \
# 0         $425,000,000   $760,507,625  $2,776,345,279    17060  tt1775309
# 1         $410,600,000   $241,063,875  $1,045,663,875     6448  tt1298650
# 2         $350,000,000    $42,762,350    $149,762,350   112147  tt6565702
# 3         $330,600,000   $459,005,868  $1,403,013,963    39010  tt2395427
# 4         $300,000,000   $678,815,482  $2,048,134,200    72820  tt4154756
# ...                ...            ...             ...      ...        ...
# 3808           $10,000       $138,711        $138,711   112803  tt6619196
# 3809           $10,000        $94,596         $94,596    21177  tt1872026
# 3812            $9,000         $4,584          $4,584    21418  tt1880418
# 3813            $7,000             $0              $0   127755  tt7837402
# 3814            $1,400             $0              $0    28674  tt2107644
#
#                                     primary_title  \
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# 3                         Avengers: Age of Ultron
# 4                          Avengers: Infinity War
# ...                                           ...
# 3808                                        Clean
# 3809                                         Cure
# 3812                                    Newlyweds
# 3813                                       Red 11
# 3814                         A Plague So Pleasant
#
#                                    original_title  start_year  \
# 0                                           Abatâ        2011
# 1     Pirates of the Caribbean: On Stranger Tides        2011
# 2                                    Dark Phoenix        2019
# 3                         Avengers: Age of Ultron        2015
# 4                          Avengers: Infinity War        2018
# ...                                           ...         ...
# 3808                                        Clean        2017
# 3809                                         Cure        2011
# 3812                                    Newlyweds        2011
# 3813                                       Red 11        2019
# 3814                         A Plague So Pleasant        2013
#
#       runtime_minutes genre 1    genre 2   genre 3
# 0                93.0  Horror       None      None
# 1               136.0  Action  Adventure   Fantasy
# 2               113.0  Action  Adventure    Sci-Fi
# 3               141.0  Action  Adventure    Sci-Fi
# 4               149.0  Action  Adventure    Sci-Fi
# ...               ...     ...        ...       ...
# 3808             70.0  Comedy      Drama    Horror
# 3809             93.0   Drama       None      None
# 3812             95.0  Comedy      Drama      None
# 3813             77.0  Horror     Sci-Fi  Thriller
# 3814             76.0   Drama     Horror  Thriller
#
# [3309 rows x 16 columns]

# %%
clean_df = combined_df.drop(columns = ['release_date', 'tconst', 'primary_title', 'original_title', 'start_year', 'runtime_minutes'])

# %%
clean_df
# Out:
#       index_x  id                                        movie  \
# 0           0   1                                       Avatar
# 1           1   2  Pirates of the Caribbean: On Stranger Tides
# 2           2   3                                 Dark Phoenix
# 3           3   4                      Avengers: Age of Ultron
# 4           6   7                       Avengers: Infinity War
# ...       ...  ..                                          ...
# 3808     5766  67                                        Clean
# 3809     5767  68                                         Cure
# 3812     5772  73                                    Newlyweds
# 3813     5777  78                                       Red 11
# 3814     5780  81                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross  index_y genre 1  \
# 0         $425,000,000   $760,507,625  $2,776,345,279    17060  Horror
# 1         $410,600,000   $241,063,875  $1,045,663,875     6448  Action
# 2         $350,000,000    $42,762,350    $149,762,350   112147  Action
# 3         $330,600,000   $459,005,868  $1,403,013,963    39010  Action
# 4         $300,000,000   $678,815,482  $2,048,134,200    72820  Action
# ...                ...            ...             ...      ...     ...
# 3808           $10,000       $138,711        $138,711   112803  Comedy
# 3809           $10,000        $94,596         $94,596    21177   Drama
# 3812            $9,000         $4,584          $4,584    21418  Comedy
# 3813            $7,000             $0              $0   127755  Horror
# 3814            $1,400             $0              $0    28674   Drama
#
#         genre 2   genre 3
# 0          None      None
# 1     Adventure   Fantasy
# 2     Adventure    Sci-Fi
# 3     Adventure    Sci-Fi
# 4     Adventure    Sci-Fi
# ...         ...       ...
# 3808      Drama    Horror
# 3809       None      None
# 3812      Drama      None
# 3813     Sci-Fi  Thriller
# 3814     Horror  Thriller
#
# [3309 rows x 10 columns]

# %%
column_values = clean_df[['genre 1', 'genre 2', 'genre 3']].values.ravel()
unique_values = pd.unique(column_values)
unique_values
# Out:
# array(['Horror', None, 'Action', 'Adventure', 'Fantasy', 'Sci-Fi',
#        'Thriller', 'Western', 'Animation', 'Comedy', 'Family', 'Crime',
#        'Drama', 'History', 'Documentary', 'Musical', 'Romance', 'Mystery',
#        'Biography', 'Sport', 'News', 'War', 'Music', 'Reality-TV'],
#       dtype=object)

# %%
genre_1 = clean_df['genre 1'].value_counts()
print(genre_1)
genre_2 = clean_df['genre 2'].value_counts()
print(genre_2)
genre_3 = clean_df['genre 3'].value_counts()
print(genre_3)
# Out:
# Drama          815
# Action         647
# Comedy         525
# Documentary    340
# Adventure      233
# Biography      213
# Horror         198
# Crime          156
# Thriller        56
# Animation       31
# Family          19
# Sci-Fi          18
# Romance         14
# Fantasy         13
# Mystery         13
# Musical          7
# Music            6
# War              2
# Western          2
# Sport            1
# Name: genre 1, dtype: int64
# Drama          613
# Adventure      236
# Thriller       175
# Romance        172
# Crime          168
# Comedy         155
# Mystery        138
# Horror         122
# Documentary     91
# Family          90
# Animation       89
# Fantasy         79
# Sci-Fi          50
# Music           48
# History         33
# Biography       29
# Sport           22
# War             12
# Musical          7
# Western          6
# News             5
# Name: genre 2, dtype: int64
# Thriller       313
# Drama          213
# Romance        164
# Sci-Fi         144
# Comedy         113
# Fantasy         92
# Mystery         82
# Family          80
# Horror          61
# History         57
# Crime           55
# Sport           47
# War             34
# Music           30
# Documentary     21
# Animation       17
# Musical         14
# Western         10
# Biography        5
# News             2
# Reality-TV       1
# Name: genre 3, dtype: int64

# %%
data = [genre_1, genre_2, genre_3]
headers = ['genre 1', 'genre 2', 'genre 3']
genre_df = pd.concat(data, axis = 1, keys = headers)

# %%
genre_df
# Out:
#              genre 1  genre 2  genre 3
# Drama          815.0    613.0    213.0
# Action         647.0      NaN      NaN
# Comedy         525.0    155.0    113.0
# Documentary    340.0     91.0     21.0
# Adventure      233.0    236.0      NaN
# Biography      213.0     29.0      5.0
# Horror         198.0    122.0     61.0
# Crime          156.0    168.0     55.0
# Thriller        56.0    175.0    313.0
# Animation       31.0     89.0     17.0
# Family          19.0     90.0     80.0
# Sci-Fi          18.0     50.0    144.0
# Romance         14.0    172.0    164.0
# Fantasy         13.0     79.0     92.0
# Mystery         13.0    138.0     82.0
# Musical          7.0      7.0     14.0
# Music            6.0     48.0     30.0
# War              2.0     12.0     34.0
# Western          2.0      6.0     10.0
# Sport            1.0     22.0     47.0
# History          NaN     33.0     57.0
# News             NaN      5.0      2.0
# Reality-TV       NaN      NaN      1.0

# %%
genre_df['total'] = genre_df.sum(axis=1)
print(genre_df)
# Out:
#              genre 1  genre 2  genre 3   total
# Drama          815.0    613.0    213.0  1641.0
# Action         647.0      NaN      NaN   647.0
# Comedy         525.0    155.0    113.0   793.0
# Documentary    340.0     91.0     21.0   452.0
# Adventure      233.0    236.0      NaN   469.0
# Biography      213.0     29.0      5.0   247.0
# Horror         198.0    122.0     61.0   381.0
# Crime          156.0    168.0     55.0   379.0
# Thriller        56.0    175.0    313.0   544.0
# Animation       31.0     89.0     17.0   137.0
# Family          19.0     90.0     80.0   189.0
# Sci-Fi          18.0     50.0    144.0   212.0
# Romance         14.0    172.0    164.0   350.0
# Fantasy         13.0     79.0     92.0   184.0
# Mystery         13.0    138.0     82.0   233.0
# Musical          7.0      7.0     14.0    28.0
# Music            6.0     48.0     30.0    84.0
# War              2.0     12.0     34.0    48.0
# Western          2.0      6.0     10.0    18.0
# Sport            1.0     22.0     47.0    70.0
# History          NaN     33.0     57.0    90.0
# News             NaN      5.0      2.0     7.0
# Reality-TV       NaN      NaN      1.0     1.0

# %%
clean_df['production_budget'] = clean_df['production_budget'].map(lambda x: x.lstrip('$').rstrip(','))
clean_df['production_budget'] = clean_df['production_budget'].str.replace(',','')
clean_df['domestic_gross'] = clean_df['domestic_gross'].map(lambda x: x.lstrip('$').rstrip(','))
clean_df['domestic_gross'] = clean_df['domestic_gross'].str.replace(',','')
clean_df['worldwide_gross'] = clean_df['worldwide_gross'].map(lambda x: x.lstrip('$').rstrip(','))
clean_df['worldwide_gross'] = clean_df['worldwide_gross'].str.replace(',','')

# %%
clean_df
# Out:
#       index_x  id                                        movie  \
# 0           0   1                                       Avatar
# 1           1   2  Pirates of the Caribbean: On Stranger Tides
# 2           2   3                                 Dark Phoenix
# 3           3   4                      Avengers: Age of Ultron
# 4           6   7                       Avengers: Infinity War
# ...       ...  ..                                          ...
# 3808     5766  67                                        Clean
# 3809     5767  68                                         Cure
# 3812     5772  73                                    Newlyweds
# 3813     5777  78                                       Red 11
# 3814     5780  81                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross  index_y genre 1  \
# 0            425000000      760507625      2776345279    17060  Horror
# 1            410600000      241063875      1045663875     6448  Action
# 2            350000000       42762350       149762350   112147  Action
# 3            330600000      459005868      1403013963    39010  Action
# 4            300000000      678815482      2048134200    72820  Action
# ...                ...            ...             ...      ...     ...
# 3808             10000         138711          138711   112803  Comedy
# 3809             10000          94596           94596    21177   Drama
# 3812              9000           4584            4584    21418  Comedy
# 3813              7000              0               0   127755  Horror
# 3814              1400              0               0    28674   Drama
#
#         genre 2   genre 3
# 0          None      None
# 1     Adventure   Fantasy
# 2     Adventure    Sci-Fi
# 3     Adventure    Sci-Fi
# 4     Adventure    Sci-Fi
# ...         ...       ...
# 3808      Drama    Horror
# 3809       None      None
# 3812      Drama      None
# 3813     Sci-Fi  Thriller
# 3814     Horror  Thriller
#
# [3309 rows x 10 columns]

# %%
clean_df['production_budget'] = pd.to_numeric(clean_df['production_budget'])
clean_df['domestic_gross'] = pd.to_numeric(clean_df['domestic_gross'])
clean_df['worldwide_gross'] = pd.to_numeric(clean_df['worldwide_gross'])

# %%
clean_df
# Out:
#       index_x  id                                        movie  \
# 0           0   1                                       Avatar
# 1           1   2  Pirates of the Caribbean: On Stranger Tides
# 2           2   3                                 Dark Phoenix
# 3           3   4                      Avengers: Age of Ultron
# 4           6   7                       Avengers: Infinity War
# ...       ...  ..                                          ...
# 3808     5766  67                                        Clean
# 3809     5767  68                                         Cure
# 3812     5772  73                                    Newlyweds
# 3813     5777  78                                       Red 11
# 3814     5780  81                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  index_y genre 1  \
# 0             425000000       760507625       2776345279    17060  Horror
# 1             410600000       241063875       1045663875     6448  Action
# 2             350000000        42762350        149762350   112147  Action
# 3             330600000       459005868       1403013963    39010  Action
# 4             300000000       678815482       2048134200    72820  Action
# ...                 ...             ...              ...      ...     ...
# 3808              10000          138711           138711   112803  Comedy
# 3809              10000           94596            94596    21177   Drama
# 3812               9000            4584             4584    21418  Comedy
# 3813               7000               0                0   127755  Horror
# 3814               1400               0                0    28674   Drama
#
#         genre 2   genre 3
# 0          None      None
# 1     Adventure   Fantasy
# 2     Adventure    Sci-Fi
# 3     Adventure    Sci-Fi
# 4     Adventure    Sci-Fi
# ...         ...       ...
# 3808      Drama    Horror
# 3809       None      None
# 3812      Drama      None
# 3813     Sci-Fi  Thriller
# 3814     Horror  Thriller
#
# [3309 rows x 10 columns]

# %%
clean_df['domestic_profit'] = clean_df['domestic_gross'] - clean_df['production_budget']
clean_df['worldwide_profit'] = clean_df['worldwide_gross'] - clean_df['production_budget']

# %%
clean_df
# Out:
#       index_x  id                                        movie  \
# 0           0   1                                       Avatar
# 1           1   2  Pirates of the Caribbean: On Stranger Tides
# 2           2   3                                 Dark Phoenix
# 3           3   4                      Avengers: Age of Ultron
# 4           6   7                       Avengers: Infinity War
# ...       ...  ..                                          ...
# 3808     5766  67                                        Clean
# 3809     5767  68                                         Cure
# 3812     5772  73                                    Newlyweds
# 3813     5777  78                                       Red 11
# 3814     5780  81                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  index_y genre 1  \
# 0             425000000       760507625       2776345279    17060  Horror
# 1             410600000       241063875       1045663875     6448  Action
# 2             350000000        42762350        149762350   112147  Action
# 3             330600000       459005868       1403013963    39010  Action
# 4             300000000       678815482       2048134200    72820  Action
# ...                 ...             ...              ...      ...     ...
# 3808              10000          138711           138711   112803  Comedy
# 3809              10000           94596            94596    21177   Drama
# 3812               9000            4584             4584    21418  Comedy
# 3813               7000               0                0   127755  Horror
# 3814               1400               0                0    28674   Drama
#
#         genre 2   genre 3  domestic_profit  worldwide_profit
# 0          None      None        335507625        2351345279
# 1     Adventure   Fantasy       -169536125         635063875
# 2     Adventure    Sci-Fi       -307237650        -200237650
# 3     Adventure    Sci-Fi        128405868        1072413963
# 4     Adventure    Sci-Fi        378815482        1748134200
# ...         ...       ...              ...               ...
# 3808      Drama    Horror           128711            128711
# 3809       None      None            84596             84596
# 3812      Drama      None            -4416             -4416
# 3813     Sci-Fi  Thriller            -7000             -7000
# 3814     Horror  Thriller            -1400             -1400
#
# [3309 rows x 12 columns]

# %%
profit_df = clean_df.drop(['index_x','id','index_y', 'genre 2', 'genre 3'], axis=1)

# %%
profit_df
# Out:
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# 4                          Avengers: Infinity War          300000000
# ...                                           ...                ...
# 3808                                        Clean              10000
# 3809                                         Cure              10000
# 3812                                    Newlyweds               9000
# 3813                                       Red 11               7000
# 3814                         A Plague So Pleasant               1400
#
#       domestic_gross  worldwide_gross genre 1  domestic_profit  \
# 0          760507625       2776345279  Horror        335507625
# 1          241063875       1045663875  Action       -169536125
# 2           42762350        149762350  Action       -307237650
# 3          459005868       1403013963  Action        128405868
# 4          678815482       2048134200  Action        378815482
# ...              ...              ...     ...              ...
# 3808          138711           138711  Comedy           128711
# 3809           94596            94596   Drama            84596
# 3812            4584             4584  Comedy            -4416
# 3813               0                0  Horror            -7000
# 3814               0                0   Drama            -1400
#
#       worldwide_profit
# 0           2351345279
# 1            635063875
# 2           -200237650
# 3           1072413963
# 4           1748134200
# ...                ...
# 3808            128711
# 3809             84596
# 3812             -4416
# 3813             -7000
# 3814             -1400
#
# [3309 rows x 7 columns]

# %%
profitbygenre_df= profit_df.groupby(profit_df['genre 1']).sum()
print(profitbygenre_df)
# Out:
#              production_budget  domestic_gross  worldwide_gross  \
# genre 1
# Action             41956540000     44994983917     120690576940
# Adventure          15074224106     18668912289      50782497531
# Animation           1298077247      2324059644       5343731948
# Biography           5224332746      7028822517      13968204681
# Comedy             10767417173     15827755378      29298589768
# Crime               3461617373      3662805754       7782134676
# Documentary         8760426897     10558091023      22375353592
# Drama              15870840469     19457973002      39869730843
# Family               815000000      2859768635       6943741278
# Fantasy              588000000      1166073329       3375101644
# Horror              3378228373      6596103936      14742990514
# Music                129000000       294562428        816440836
# Musical              227300000       618430954       1672813784
# Mystery              371150000       572315170       1190651137
# Romance              304650000       246255684        402865766
# Sci-Fi               537190000       932355050       1920162754
# Sport                 19000000         5310554          5745503
# Thriller            1546765732      1535825985       3713000418
# War                   44000000        51949105         51949105
# Western               13000000        65532576         65532576
#
#              domestic_profit  worldwide_profit
# genre 1
# Action            3038443917       78734036940
# Adventure         3594688183       35708273425
# Animation         1025982397        4045654701
# Biography         1804489771        8743871935
# Comedy            5060338205       18531172595
# Crime              201188381        4320517303
# Documentary       1797664126       13614926695
# Drama             3587132533       23998890374
# Family            2044768635        6128741278
# Fantasy            578073329        2787101644
# Horror            3217875563       11364762141
# Music              165562428         687440836
# Musical            391130954        1445513784
# Mystery            201165170         819501137
# Romance            -58394316          98215766
# Sci-Fi             395165050        1382972754
# Sport              -13689446         -13254497
# Thriller           -10939747        2166234686
# War                  7949105           7949105
# Western             52532576          52532576

# %%
ppmbgtemp_df = pd.concat([profitbygenre_df, genre_df['genre 1']], axis=1)
ppmbgtemp_df
# Out:
#              production_budget  domestic_gross  worldwide_gross  \
# Action            4.195654e+10    4.499498e+10     1.206906e+11
# Adventure         1.507422e+10    1.866891e+10     5.078250e+10
# Animation         1.298077e+09    2.324060e+09     5.343732e+09
# Biography         5.224333e+09    7.028823e+09     1.396820e+10
# Comedy            1.076742e+10    1.582776e+10     2.929859e+10
# Crime             3.461617e+09    3.662806e+09     7.782135e+09
# Documentary       8.760427e+09    1.055809e+10     2.237535e+10
# Drama             1.587084e+10    1.945797e+10     3.986973e+10
# Family            8.150000e+08    2.859769e+09     6.943741e+09
# Fantasy           5.880000e+08    1.166073e+09     3.375102e+09
# Horror            3.378228e+09    6.596104e+09     1.474299e+10
# Music             1.290000e+08    2.945624e+08     8.164408e+08
# Musical           2.273000e+08    6.184310e+08     1.672814e+09
# Mystery           3.711500e+08    5.723152e+08     1.190651e+09
# Romance           3.046500e+08    2.462557e+08     4.028658e+08
# Sci-Fi            5.371900e+08    9.323550e+08     1.920163e+09
# Sport             1.900000e+07    5.310554e+06     5.745503e+06
# Thriller          1.546766e+09    1.535826e+09     3.713000e+09
# War               4.400000e+07    5.194910e+07     5.194910e+07
# Western           1.300000e+07    6.553258e+07     6.553258e+07
# History                    NaN             NaN              NaN
# News                       NaN             NaN              NaN
# Reality-TV                 NaN             NaN              NaN
#
#              domestic_profit  worldwide_profit  genre 1
# Action          3.038444e+09      7.873404e+10    647.0
# Adventure       3.594688e+09      3.570827e+10    233.0
# Animation       1.025982e+09      4.045655e+09     31.0
# Biography       1.804490e+09      8.743872e+09    213.0
# Comedy          5.060338e+09      1.853117e+10    525.0
# Crime           2.011884e+08      4.320517e+09    156.0
# Documentary     1.797664e+09      1.361493e+10    340.0
# Drama           3.587133e+09      2.399889e+10    815.0
# Family          2.044769e+09      6.128741e+09     19.0
# Fantasy         5.780733e+08      2.787102e+09     13.0
# Horror          3.217876e+09      1.136476e+10    198.0
# Music           1.655624e+08      6.874408e+08      6.0
# Musical         3.911310e+08      1.445514e+09      7.0
# Mystery         2.011652e+08      8.195011e+08     13.0
# Romance        -5.839432e+07      9.821577e+07     14.0
# Sci-Fi          3.951650e+08      1.382973e+09     18.0
# Sport          -1.368945e+07     -1.325450e+07      1.0
# Thriller       -1.093975e+07      2.166235e+09     56.0
# War             7.949105e+06      7.949105e+06      2.0
# Western         5.253258e+07      5.253258e+07      2.0
# History                  NaN               NaN      NaN
# News                     NaN               NaN      NaN
# Reality-TV               NaN               NaN      NaN

# %%
ppmbgtemp_df = ppmbgtemp_df.astype(float)
ppmbgtemp_df
# Out:
#              production_budget  domestic_gross  worldwide_gross  \
# Action            4.195654e+10    4.499498e+10     1.206906e+11
# Adventure         1.507422e+10    1.866891e+10     5.078250e+10
# Animation         1.298077e+09    2.324060e+09     5.343732e+09
# Biography         5.224333e+09    7.028823e+09     1.396820e+10
# Comedy            1.076742e+10    1.582776e+10     2.929859e+10
# Crime             3.461617e+09    3.662806e+09     7.782135e+09
# Documentary       8.760427e+09    1.055809e+10     2.237535e+10
# Drama             1.587084e+10    1.945797e+10     3.986973e+10
# Family            8.150000e+08    2.859769e+09     6.943741e+09
# Fantasy           5.880000e+08    1.166073e+09     3.375102e+09
# Horror            3.378228e+09    6.596104e+09     1.474299e+10
# Music             1.290000e+08    2.945624e+08     8.164408e+08
# Musical           2.273000e+08    6.184310e+08     1.672814e+09
# Mystery           3.711500e+08    5.723152e+08     1.190651e+09
# Romance           3.046500e+08    2.462557e+08     4.028658e+08
# Sci-Fi            5.371900e+08    9.323550e+08     1.920163e+09
# Sport             1.900000e+07    5.310554e+06     5.745503e+06
# Thriller          1.546766e+09    1.535826e+09     3.713000e+09
# War               4.400000e+07    5.194910e+07     5.194910e+07
# Western           1.300000e+07    6.553258e+07     6.553258e+07
# History                    NaN             NaN              NaN
# News                       NaN             NaN              NaN
# Reality-TV                 NaN             NaN              NaN
#
#              domestic_profit  worldwide_profit  genre 1
# Action          3.038444e+09      7.873404e+10    647.0
# Adventure       3.594688e+09      3.570827e+10    233.0
# Animation       1.025982e+09      4.045655e+09     31.0
# Biography       1.804490e+09      8.743872e+09    213.0
# Comedy          5.060338e+09      1.853117e+10    525.0
# Crime           2.011884e+08      4.320517e+09    156.0
# Documentary     1.797664e+09      1.361493e+10    340.0
# Drama           3.587133e+09      2.399889e+10    815.0
# Family          2.044769e+09      6.128741e+09     19.0
# Fantasy         5.780733e+08      2.787102e+09     13.0
# Horror          3.217876e+09      1.136476e+10    198.0
# Music           1.655624e+08      6.874408e+08      6.0
# Musical         3.911310e+08      1.445514e+09      7.0
# Mystery         2.011652e+08      8.195011e+08     13.0
# Romance        -5.839432e+07      9.821577e+07     14.0
# Sci-Fi          3.951650e+08      1.382973e+09     18.0
# Sport          -1.368945e+07     -1.325450e+07      1.0
# Thriller       -1.093975e+07      2.166235e+09     56.0
# War             7.949105e+06      7.949105e+06      2.0
# Western         5.253258e+07      5.253258e+07      2.0
# History                  NaN               NaN      NaN
# News                     NaN               NaN      NaN
# Reality-TV               NaN               NaN      NaN

# %%
productionbudget_df = ppmbgtemp_df.apply(lambda x: x['production_budget']/x['genre 1'], axis =1)
domesticgross_df = ppmbgtemp_df.apply(lambda x: x['domestic_gross']/x['genre 1'], axis =1)
worldwidegross_df = ppmbgtemp_df.apply(lambda x: x['worldwide_gross']/x['genre 1'], axis =1)
domesticprofit_df = ppmbgtemp_df.apply(lambda x: x['domestic_profit']/x['genre 1'], axis =1)
worldwideprofit_df = ppmbgtemp_df.apply(lambda x: x['worldwide_profit']/x['genre 1'], axis =1)
average_df = pd.concat([productionbudget_df, domesticgross_df, worldwidegross_df, domesticprofit_df, worldwideprofit_df], axis=1)
average_df
# Out:
#                         0             1             2             3  \
# Action       6.484782e+07  6.954402e+07  1.865388e+08  4.696204e+06
# Adventure    6.469624e+07  8.012409e+07  2.179506e+08  1.542785e+07
# Animation    4.187346e+07  7.496967e+07  1.723784e+08  3.309621e+07
# Biography    2.452738e+07  3.299917e+07  6.557843e+07  8.471783e+06
# Comedy       2.050937e+07  3.014811e+07  5.580684e+07  9.638739e+06
# Crime        2.218985e+07  2.347952e+07  4.988548e+07  1.289669e+06
# Documentary  2.576596e+07  3.105321e+07  6.580986e+07  5.287247e+06
# Drama        1.947342e+07  2.387481e+07  4.891992e+07  4.401390e+06
# Family       4.289474e+07  1.505141e+08  3.654601e+08  1.076194e+08
# Fantasy      4.523077e+07  8.969795e+07  2.596232e+08  4.446718e+07
# Horror       1.706176e+07  3.331366e+07  7.445955e+07  1.625190e+07
# Music        2.150000e+07  4.909374e+07  1.360735e+08  2.759374e+07
# Musical      3.247143e+07  8.834728e+07  2.389734e+08  5.587585e+07
# Mystery      2.855000e+07  4.402424e+07  9.158855e+07  1.547424e+07
# Romance      2.176071e+07  1.758969e+07  2.877613e+07 -4.171023e+06
# Sci-Fi       2.984389e+07  5.179750e+07  1.066757e+08  2.195361e+07
# Sport        1.900000e+07  5.310554e+06  5.745503e+06 -1.368945e+07
# Thriller     2.762082e+07  2.742546e+07  6.630358e+07 -1.953526e+05
# War          2.200000e+07  2.597455e+07  2.597455e+07  3.974552e+06
# Western      6.500000e+06  3.276629e+07  3.276629e+07  2.626629e+07
# History               NaN           NaN           NaN           NaN
# News                  NaN           NaN           NaN           NaN
# Reality-TV            NaN           NaN           NaN           NaN
#
#                         4
# Action       1.216909e+08
# Adventure    1.532544e+08
# Animation    1.305050e+08
# Biography    4.105104e+07
# Comedy       3.529747e+07
# Crime        2.769562e+07
# Documentary  4.004390e+07
# Drama        2.944649e+07
# Family       3.225653e+08
# Fantasy      2.143924e+08
# Horror       5.739779e+07
# Music        1.145735e+08
# Musical      2.065020e+08
# Mystery      6.303855e+07
# Romance      7.015412e+06
# Sci-Fi       7.683182e+07
# Sport       -1.325450e+07
# Thriller     3.868276e+07
# War          3.974552e+06
# Western      2.626629e+07
# History               NaN
# News                  NaN
# Reality-TV            NaN

# %%
xfinalaverage_df = average_df.rename(columns={0: "Avg Production Budget", 1: "Avg Domestic Gross", 2: "Avg Worldwide Gross", 3: "Avg Domestic Profit", 4: "Avg Worldwide Profit"})

# %%
finalaverage_df = xfinalaverage_df.sort_values(by=['Avg Worldwide Profit'], ascending=False)
finalaverage_df
# Out:
#              Avg Production Budget  Avg Domestic Gross  Avg Worldwide Gross  \
# Family                4.289474e+07        1.505141e+08         3.654601e+08
# Fantasy               4.523077e+07        8.969795e+07         2.596232e+08
# Musical               3.247143e+07        8.834728e+07         2.389734e+08
# Adventure             6.469624e+07        8.012409e+07         2.179506e+08
# Animation             4.187346e+07        7.496967e+07         1.723784e+08
# Action                6.484782e+07        6.954402e+07         1.865388e+08
# Music                 2.150000e+07        4.909374e+07         1.360735e+08
# Sci-Fi                2.984389e+07        5.179750e+07         1.066757e+08
# Mystery               2.855000e+07        4.402424e+07         9.158855e+07
# Horror                1.706176e+07        3.331366e+07         7.445955e+07
# Biography             2.452738e+07        3.299917e+07         6.557843e+07
# Documentary           2.576596e+07        3.105321e+07         6.580986e+07
# Thriller              2.762082e+07        2.742546e+07         6.630358e+07
# Comedy                2.050937e+07        3.014811e+07         5.580684e+07
# Drama                 1.947342e+07        2.387481e+07         4.891992e+07
# Crime                 2.218985e+07        2.347952e+07         4.988548e+07
# Western               6.500000e+06        3.276629e+07         3.276629e+07
# Romance               2.176071e+07        1.758969e+07         2.877613e+07
# War                   2.200000e+07        2.597455e+07         2.597455e+07
# Sport                 1.900000e+07        5.310554e+06         5.745503e+06
# History                        NaN                 NaN                  NaN
# News                           NaN                 NaN                  NaN
# Reality-TV                     NaN                 NaN                  NaN
#
#              Avg Domestic Profit  Avg Worldwide Profit
# Family              1.076194e+08          3.225653e+08
# Fantasy             4.446718e+07          2.143924e+08
# Musical             5.587585e+07          2.065020e+08
# Adventure           1.542785e+07          1.532544e+08
# Animation           3.309621e+07          1.305050e+08
# Action              4.696204e+06          1.216909e+08
# Music               2.759374e+07          1.145735e+08
# Sci-Fi              2.195361e+07          7.683182e+07
# Mystery             1.547424e+07          6.303855e+07
# Horror              1.625190e+07          5.739779e+07
# Biography           8.471783e+06          4.105104e+07
# Documentary         5.287247e+06          4.004390e+07
# Thriller           -1.953526e+05          3.868276e+07
# Comedy              9.638739e+06          3.529747e+07
# Drama               4.401390e+06          2.944649e+07
# Crime               1.289669e+06          2.769562e+07
# Western             2.626629e+07          2.626629e+07
# Romance            -4.171023e+06          7.015412e+06
# War                 3.974552e+06          3.974552e+06
# Sport              -1.368945e+07         -1.325450e+07
# History                      NaN                   NaN
# News                         NaN                   NaN
# Reality-TV                   NaN                   NaN

# %%
finalaverage_df.reset_index(inplace = True)

# %%
finalaverage_df.rename(columns={'index': 'Genre'}, inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.barplot(y = 'Genre', x = 'Avg Worldwide Gross', palette = 'flare', data = finalaverage_df.iloc[0:10])
plt.title('Average Worldwide Gross by Genre')
plt.xlabel('Average Worldwide Gross')
sns.set_style("ticks")
sns.despine()

# %% [markdown]
# # 2) Exceptionalism:
# What genre of movies have been the highest rated? ie; ratings

# %%
df1 = pd.read_csv("C:/Users/User/Documents/Phase_1/imdb.title.ratings.csv.gz")
df2 = pd.read_csv("C:/Users/User/Documents/Phase_1/imdb.title.basics.csv.gz")

# %%
df1.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
df2.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
df3 = df1.reset_index()

# %%
df4 = df2.reset_index()

# %%
df3.columns
# Out:
# Index(['index', 'tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
df4.columns
# Out:
# Index(['index', 'tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
combined_df = df3.merge(df4, left_on = 'tconst', right_on = 'tconst', how = 'inner')
combined_df
# Out:
#        index_x      tconst  averagerating  numvotes  index_y  \
# 0            0  tt10356526            8.3        31     3667
# 1            1  tt10384606            8.9       559     4103
# 2            2   tt1042974            6.4        20     4721
# 3            3   tt1043726            4.2     50352     4825
# 4            4   tt1060240            6.5        21     5471
# ...        ...         ...            ...       ...      ...
# 73851    73851   tt9805820            8.1        25   145351
# 73852    73852   tt9844256            7.5        24   145600
# 73853    73853   tt9851050            4.7        14   145664
# 73854    73854   tt9886934            7.0         5   145919
# 73855    73855   tt9894098            6.3       128   145992
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# 73851                                              Caisa
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...
# 73853                                            Sisters
# 73854                                  The Projectionist
# 73855                                             Sathru
#
#                                          original_title  start_year  \
# 0                                      Laiye Je Yaarian        2019
# 1                                            Borderless        2019
# 2                                             Just Inès        2010
# 3                                The Legend of Hercules        2014
# 4                                             Até Onde?        2011
# ...                                                 ...         ...
# 73851                                             Caisa        2018
# 73852  Code Geass: Lelouch of the Rebellion Episode III        2018
# 73853                                           Sisters        2019
# 73854                                 The Projectionist        2019
# 73855                                            Sathru        2019
#
#        runtime_minutes                    genres
# 0                117.0                   Romance
# 1                 87.0               Documentary
# 2                 90.0                     Drama
# 3                 99.0  Action,Adventure,Fantasy
# 4                 73.0          Mystery,Thriller
# ...                ...                       ...
# 73851             84.0               Documentary
# 73852            120.0   Action,Animation,Sci-Fi
# 73853              NaN              Action,Drama
# 73854             81.0               Documentary
# 73855            129.0                  Thriller
#
# [73856 rows x 10 columns]

# %%
combined_df.dropna(inplace = True)
newcombined_df = combined_df['genres'].str.split(',', n=0, expand = True)
combined_df['Genre'] = newcombined_df[0]
combined_df.drop(columns = 'genres', inplace = True)
combined_df
# Out:
#        index_x      tconst  averagerating  numvotes  index_y  \
# 0            0  tt10356526            8.3        31     3667
# 1            1  tt10384606            8.9       559     4103
# 2            2   tt1042974            6.4        20     4721
# 3            3   tt1043726            4.2     50352     4825
# 4            4   tt1060240            6.5        21     5471
# ...        ...         ...            ...       ...      ...
# 73849    73849   tt9768966            8.6        27   145093
# 73851    73851   tt9805820            8.1        25   145351
# 73852    73852   tt9844256            7.5        24   145600
# 73854    73854   tt9886934            7.0         5   145919
# 73855    73855   tt9894098            6.3       128   145992
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# 73849                                         Plugged in
# 73851                                              Caisa
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...
# 73854                                  The Projectionist
# 73855                                             Sathru
#
#                                          original_title  start_year  \
# 0                                      Laiye Je Yaarian        2019
# 1                                            Borderless        2019
# 2                                             Just Inès        2010
# 3                                The Legend of Hercules        2014
# 4                                             Até Onde?        2011
# ...                                                 ...         ...
# 73849                                        Plugged in        2019
# 73851                                             Caisa        2018
# 73852  Code Geass: Lelouch of the Rebellion Episode III        2018
# 73854                                 The Projectionist        2019
# 73855                                            Sathru        2019
#
#        runtime_minutes        Genre
# 0                117.0      Romance
# 1                 87.0  Documentary
# 2                 90.0        Drama
# 3                 99.0       Action
# 4                 73.0      Mystery
# ...                ...          ...
# 73849             53.0  Documentary
# 73851             84.0  Documentary
# 73852            120.0       Action
# 73854             81.0  Documentary
# 73855            129.0     Thriller
#
# [65720 rows x 10 columns]

# %%
clean_df = combined_df.drop(columns = ['index_x', 'tconst', 'index_y', 'original_title', 'start_year', 'runtime_minutes'])
clean_df
# Out:
#        averagerating  numvotes  \
# 0                8.3        31
# 1                8.9       559
# 2                6.4        20
# 3                4.2     50352
# 4                6.5        21
# ...              ...       ...
# 73849            8.6        27
# 73851            8.1        25
# 73852            7.5        24
# 73854            7.0         5
# 73855            6.3       128
#
#                                            primary_title        Genre
# 0                                       Laiye Je Yaarian      Romance
# 1                                             Borderless  Documentary
# 2                                              Just Inès        Drama
# 3                                 The Legend of Hercules       Action
# 4                                              Até Onde?      Mystery
# ...                                                  ...          ...
# 73849                                         Plugged in  Documentary
# 73851                                              Caisa  Documentary
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...       Action
# 73854                                  The Projectionist  Documentary
# 73855                                             Sathru     Thriller
#
# [65720 rows x 4 columns]

# %%
column_values = clean_df['Genre'].values.ravel()
genre_values = pd.unique(column_values)
genre_values
# Out:
# array(['Romance', 'Documentary', 'Drama', 'Action', 'Mystery', 'Comedy',
#        'Biography', 'Adventure', 'Thriller', 'Sci-Fi', 'Fantasy',
#        'Horror', 'Crime', 'Family', 'Animation', 'History', 'Sport',
#        'Musical', 'Music', 'Western', 'News', 'War', 'Adult',
#        'Reality-TV', 'Game-Show'], dtype=object)

# %%
cleaned_df = clean_df[clean_df['numvotes'] >= 500]
cleaned_df
# Out:
#        averagerating  numvotes                       primary_title  \
# 1                8.9       559                          Borderless
# 3                4.2     50352              The Legend of Hercules
# 6                7.0      1613                          The Hammer
# 7                6.4       571                     The Night Clerk
# 10               5.1      8296                       Baggage Claim
# ...              ...       ...                                 ...
# 73772            7.1      1526  The Witch: Part 1 - The Subversion
# 73780            9.7       639                           Eghantham
# 73792            9.0      1778                              Jersey
# 73814            7.4       710                        Chitralahari
# 73831            3.7      4057                    PM Narendra Modi
#
#              Genre
# 1      Documentary
# 3           Action
# 6        Biography
# 7            Drama
# 10          Comedy
# ...            ...
# 73772       Action
# 73780        Drama
# 73792        Drama
# 73814        Drama
# 73831    Biography
#
# [13835 rows x 4 columns]

# %%
mean_df = cleaned_df.groupby(['Genre']).mean()
mean_df
# Out:
#              averagerating      numvotes
# Genre
# Action            5.851647  39498.754902
# Adventure         6.270533  42139.614420
# Animation         6.656410  12115.570513
# Biography         6.951975  22461.430573
# Comedy            5.987953  11542.815134
# Crime             6.216022  17972.787293
# Documentary       7.150359   2784.886364
# Drama             6.388207  12015.847720
# Family            6.050000  10154.884615
# Fantasy           5.431169   7507.766234
# History           6.080000   1038.400000
# Horror            4.853870  10790.922594
# Music             7.133333   6005.833333
# Musical           6.708333   1174.916667
# Mystery           6.164557  29721.240506
# Romance           6.310127   5244.227848
# Sci-Fi            5.067391   5085.217391
# Sport             5.700000    599.000000
# Thriller          5.624468   1851.319149
# War               6.700000   1225.333333
# Western           4.937500   1160.375000

# %%
final_df = mean_df.reset_index()
final_df
# Out:
#           Genre  averagerating      numvotes
# 0        Action       5.851647  39498.754902
# 1     Adventure       6.270533  42139.614420
# 2     Animation       6.656410  12115.570513
# 3     Biography       6.951975  22461.430573
# 4        Comedy       5.987953  11542.815134
# 5         Crime       6.216022  17972.787293
# 6   Documentary       7.150359   2784.886364
# 7         Drama       6.388207  12015.847720
# 8        Family       6.050000  10154.884615
# 9       Fantasy       5.431169   7507.766234
# 10      History       6.080000   1038.400000
# 11       Horror       4.853870  10790.922594
# 12        Music       7.133333   6005.833333
# 13      Musical       6.708333   1174.916667
# 14      Mystery       6.164557  29721.240506
# 15      Romance       6.310127   5244.227848
# 16       Sci-Fi       5.067391   5085.217391
# 17        Sport       5.700000    599.000000
# 18     Thriller       5.624468   1851.319149
# 19          War       6.700000   1225.333333
# 20      Western       4.937500   1160.375000

# %%
ffinal_df = final_df.rename(columns={'averagerating': 'Average Rating', 'numvotes': 'Average Votes'})

# %%
ffinal_df
# Out:
#           Genre  Average Rating  Average Votes
# 0        Action        5.851647   39498.754902
# 1     Adventure        6.270533   42139.614420
# 2     Animation        6.656410   12115.570513
# 3     Biography        6.951975   22461.430573
# 4        Comedy        5.987953   11542.815134
# 5         Crime        6.216022   17972.787293
# 6   Documentary        7.150359    2784.886364
# 7         Drama        6.388207   12015.847720
# 8        Family        6.050000   10154.884615
# 9       Fantasy        5.431169    7507.766234
# 10      History        6.080000    1038.400000
# 11       Horror        4.853870   10790.922594
# 12        Music        7.133333    6005.833333
# 13      Musical        6.708333    1174.916667
# 14      Mystery        6.164557   29721.240506
# 15      Romance        6.310127    5244.227848
# 16       Sci-Fi        5.067391    5085.217391
# 17        Sport        5.700000     599.000000
# 18     Thriller        5.624468    1851.319149
# 19          War        6.700000    1225.333333
# 20      Western        4.937500    1160.375000

# %%
fffinal_df = ffinal_df.sort_values(by = ['Average Rating'], ascending = False)

# %%
plt.figure(figsize=(15,8))
sns.barplot(y = 'Genre', x = 'Average Rating', palette = 'flare', data = fffinal_df.iloc[0:10])
plt.title('Average Rating by Genre')
plt.xlabel('Average Rating')
sns.set_style("ticks")
sns.despine()

# %% [markdown]
# # 3) Timing:
# When in the year have the most profitable movies been released?

# %%
df1 = pd.read_csv("C:/Users/User/Documents/Phase_1/tmdb.movies.csv.gz")
df2 = pd.read_csv("C:/Users/User/Documents/Phase_1/bom.movie_gross.csv.gz")

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
df3 = df1.reset_index()

# %%
df4 = df2.reset_index()

# %%
df3.columns
# Out:
# Index(['index', 'Unnamed: 0', 'genre_ids', 'id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['index', 'title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
combined_df = df3.merge(df4, left_on = 'original_title', right_on = 'title', how = 'inner')
combined_df
# Out:
#       index_x  Unnamed: 0            genre_ids      id original_language  \
# 0           1           1  [14, 12, 16, 10751]   10191                en
# 1           2           2        [12, 28, 878]   10138                en
# 2           4           4        [28, 878, 12]   27205                en
# 3           7           7      [16, 10751, 35]   10193                en
# 4           8           8      [16, 10751, 35]   20352                en
# ...       ...         ...                  ...     ...               ...
# 2275    24916       24916                 [18]  473262                it
# 2276    25037       25037                 [99]  465871                en
# 2277    25090       25090      [16, 10751, 12]  455842                en
# 2278    25148       25148         [28, 12, 16]  332718                en
# 2279    25189       25189                 [35]  498919                es
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# 2                         Inception      27.920   2010-07-16
# 3                       Toy Story 3      24.445   2010-06-17
# 4                     Despicable Me      23.673   2010-07-09
# ...                             ...         ...          ...
# 2275                     Nico, 1988       3.789   2018-07-04
# 2276                Maria by Callas       3.184   2018-11-02
# 2277  Elliot: The Littlest Reindeer       2.903   2018-11-30
# 2278     Bilal: A New Breed of Hero       2.707   2018-02-02
# 2279           La Boda de Valentina       2.550   2018-02-09
#
#                             title_x  vote_average  vote_count  index_y  \
# 0          How to Train Your Dragon           7.7        7610        9
# 1                        Iron Man 2           6.8       12368        6
# 2                         Inception           8.3       22186        3
# 3                       Toy Story 3           7.7        8340        0
# 4                     Despicable Me           7.2       10057        8
# ...                             ...           ...         ...      ...
# 2275                     Nico, 1988           7.3          40     3352
# 2276                Maria by Callas           7.6          11     3278
# 2277  Elliot: The Littlest Reindeer           3.4           7     3367
# 2278     Bilal: A New Breed of Hero           6.8          54     3271
# 2279           La Boda de Valentina           6.3           7     3266
#
#                             title_y studio  domestic_gross foreign_gross  year
# 0          How to Train Your Dragon   P/DW     217600000.0     277300000  2010
# 1                        Iron Man 2   Par.     312400000.0     311500000  2010
# 2                         Inception     WB     292600000.0     535700000  2010
# 3                       Toy Story 3     BV     415000000.0     652000000  2010
# 4                     Despicable Me   Uni.     251500000.0     291600000  2010
# ...                             ...    ...             ...           ...   ...
# 2275                     Nico, 1988  Magn.         73300.0           NaN  2018
# 2276                Maria by Callas    SPC       1300000.0           NaN  2018
# 2277  Elliot: The Littlest Reindeer  Scre.         24300.0           NaN  2018
# 2278     Bilal: A New Breed of Hero     VE        491000.0       1700000  2018
# 2279           La Boda de Valentina    PNT       2800000.0           NaN  2018
#
# [2280 rows x 17 columns]

# %%
combined_df.dropna(inplace = True)
newcombined_df = combined_df['release_date'].str.split("-", n=2, expand = True)
combined_df['Year'] = newcombined_df[0]
combined_df['Month Num'] = newcombined_df[1]
combined_df['Day'] = newcombined_df[2]
combined_df.drop(columns = ['index_x', 'Unnamed: 0', 'genre_ids', 'id', 'original_language', 'popularity', 'release_date', 'title_x', 'vote_average', 'vote_count', 'index_y', 'title_y', 'studio', 'year'], inplace = True)
combined_df
# Out:
#                   original_title  domestic_gross foreign_gross  Year  \
# 0       How to Train Your Dragon     217600000.0     277300000  2010
# 1                     Iron Man 2     312400000.0     311500000  2010
# 2                      Inception     292600000.0     535700000  2010
# 3                    Toy Story 3     415000000.0     652000000  2010
# 4                  Despicable Me     251500000.0     291600000  2010
# ...                          ...             ...           ...   ...
# 2264                The Bookshop       1600000.0       9900000  2018
# 2265            The Children Act        548000.0      17000000  2018
# 2268                   Show Dogs      17900000.0      21300000  2018
# 2273                  Heartbeats         68700.0        520000  2018
# 2278  Bilal: A New Breed of Hero        491000.0       1700000  2018
#
#      Month Num Day
# 0           03  26
# 1           05  07
# 2           07  16
# 3           06  17
# 4           07  09
# ...        ...  ..
# 2264        08  24
# 2265        09  14
# 2268        05  18
# 2273        03  20
# 2278        02  02
#
# [1526 rows x 6 columns]

# %%
combined_df['foreign_gross'] = combined_df['foreign_gross'].replace(',','', regex=True)
combined_df
# Out:
#                   original_title  domestic_gross foreign_gross  Year  \
# 0       How to Train Your Dragon     217600000.0     277300000  2010
# 1                     Iron Man 2     312400000.0     311500000  2010
# 2                      Inception     292600000.0     535700000  2010
# 3                    Toy Story 3     415000000.0     652000000  2010
# 4                  Despicable Me     251500000.0     291600000  2010
# ...                          ...             ...           ...   ...
# 2264                The Bookshop       1600000.0       9900000  2018
# 2265            The Children Act        548000.0      17000000  2018
# 2268                   Show Dogs      17900000.0      21300000  2018
# 2273                  Heartbeats         68700.0        520000  2018
# 2278  Bilal: A New Breed of Hero        491000.0       1700000  2018
#
#      Month Num Day
# 0           03  26
# 1           05  07
# 2           07  16
# 3           06  17
# 4           07  09
# ...        ...  ..
# 2264        08  24
# 2265        09  14
# 2268        05  18
# 2273        03  20
# 2278        02  02
#
# [1526 rows x 6 columns]

# %%
combined_df['foreign_gross'] = combined_df['foreign_gross'].astype(float)

# %%
combined_df['Worldwide Gross'] = combined_df['domestic_gross'] + combined_df['foreign_gross']
combined_df
# Out:
#                   original_title  domestic_gross  foreign_gross  Year  \
# 0       How to Train Your Dragon     217600000.0    277300000.0  2010
# 1                     Iron Man 2     312400000.0    311500000.0  2010
# 2                      Inception     292600000.0    535700000.0  2010
# 3                    Toy Story 3     415000000.0    652000000.0  2010
# 4                  Despicable Me     251500000.0    291600000.0  2010
# ...                          ...             ...            ...   ...
# 2264                The Bookshop       1600000.0      9900000.0  2018
# 2265            The Children Act        548000.0     17000000.0  2018
# 2268                   Show Dogs      17900000.0     21300000.0  2018
# 2273                  Heartbeats         68700.0       520000.0  2018
# 2278  Bilal: A New Breed of Hero        491000.0      1700000.0  2018
#
#      Month Num Day  Worldwide Gross
# 0           03  26     4.949000e+08
# 1           05  07     6.239000e+08
# 2           07  16     8.283000e+08
# 3           06  17     1.067000e+09
# 4           07  09     5.431000e+08
# ...        ...  ..              ...
# 2264        08  24     1.150000e+07
# 2265        09  14     1.754800e+07
# 2268        05  18     3.920000e+07
# 2273        03  20     5.887000e+05
# 2278        02  02     2.191000e+06
#
# [1526 rows x 7 columns]

# %%
combined_df.drop(columns = ['domestic_gross', 'foreign_gross'], inplace = True)

# %%
combined_df
# Out:
#                   original_title  Year Month Num Day  Worldwide Gross
# 0       How to Train Your Dragon  2010        03  26     4.949000e+08
# 1                     Iron Man 2  2010        05  07     6.239000e+08
# 2                      Inception  2010        07  16     8.283000e+08
# 3                    Toy Story 3  2010        06  17     1.067000e+09
# 4                  Despicable Me  2010        07  09     5.431000e+08
# ...                          ...   ...       ...  ..              ...
# 2264                The Bookshop  2018        08  24     1.150000e+07
# 2265            The Children Act  2018        09  14     1.754800e+07
# 2268                   Show Dogs  2018        05  18     3.920000e+07
# 2273                  Heartbeats  2018        03  20     5.887000e+05
# 2278  Bilal: A New Breed of Hero  2018        02  02     2.191000e+06
#
# [1526 rows x 5 columns]

# %%
combined_df.rename(columns = {'original_title': 'Title'}, inplace = True)

# %%
combined_df
# Out:
#                            Title  Year Month Num Day  Worldwide Gross
# 0       How to Train Your Dragon  2010        03  26     4.949000e+08
# 1                     Iron Man 2  2010        05  07     6.239000e+08
# 2                      Inception  2010        07  16     8.283000e+08
# 3                    Toy Story 3  2010        06  17     1.067000e+09
# 4                  Despicable Me  2010        07  09     5.431000e+08
# ...                          ...   ...       ...  ..              ...
# 2264                The Bookshop  2018        08  24     1.150000e+07
# 2265            The Children Act  2018        09  14     1.754800e+07
# 2268                   Show Dogs  2018        05  18     3.920000e+07
# 2273                  Heartbeats  2018        03  20     5.887000e+05
# 2278  Bilal: A New Breed of Hero  2018        02  02     2.191000e+06
#
# [1526 rows x 5 columns]

# %%
final_df = combined_df.groupby(by = ['Month Num'], dropna = False).mean()
final_df
# Out:
#            Worldwide Gross
# Month Num
# 01            8.937385e+07
# 02            1.312690e+08
# 03            1.269109e+08
# 04            8.299879e+07
# 05            2.320307e+08
# 06            2.423181e+08
# 07            2.085644e+08
# 08            1.042607e+08
# 09            1.021212e+08
# 10            8.761734e+07
# 11            1.911567e+08
# 12            1.896613e+08

# %%
final_df.rename(columns = {'Worldwide Gross': 'Average Worldwide Gross'}, inplace = True)

# %%
final_df
# Out:
#            Average Worldwide Gross
# Month Num
# 01                    8.937385e+07
# 02                    1.312690e+08
# 03                    1.269109e+08
# 04                    8.299879e+07
# 05                    2.320307e+08
# 06                    2.423181e+08
# 07                    2.085644e+08
# 08                    1.042607e+08
# 09                    1.021212e+08
# 10                    8.761734e+07
# 11                    1.911567e+08
# 12                    1.896613e+08

# %%
ffinal_df = final_df.reset_index()

# %%
ffinal_df
# Out:
#    Month Num  Average Worldwide Gross
# 0         01             8.937385e+07
# 1         02             1.312690e+08
# 2         03             1.269109e+08
# 3         04             8.299879e+07
# 4         05             2.320307e+08
# 5         06             2.423181e+08
# 6         07             2.085644e+08
# 7         08             1.042607e+08
# 8         09             1.021212e+08
# 9         10             8.761734e+07
# 10        11             1.911567e+08
# 11        12             1.896613e+08

# %%
ffinal_df['Month'] = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
ffinal_df
# Out:
#    Month Num  Average Worldwide Gross      Month
# 0         01             8.937385e+07    January
# 1         02             1.312690e+08   February
# 2         03             1.269109e+08      March
# 3         04             8.299879e+07      April
# 4         05             2.320307e+08        May
# 5         06             2.423181e+08       June
# 6         07             2.085644e+08       July
# 7         08             1.042607e+08     August
# 8         09             1.021212e+08  September
# 9         10             8.761734e+07    October
# 10        11             1.911567e+08   November
# 11        12             1.896613e+08   December

# %%
ffinal_df.drop(columns = ['Month Num'], inplace = True)

# %%
ffinal_df
# Out:
#     Average Worldwide Gross      Month
# 0              8.937385e+07    January
# 1              1.312690e+08   February
# 2              1.269109e+08      March
# 3              8.299879e+07      April
# 4              2.320307e+08        May
# 5              2.423181e+08       June
# 6              2.085644e+08       July
# 7              1.042607e+08     August
# 8              1.021212e+08  September
# 9              8.761734e+07    October
# 10             1.911567e+08   November
# 11             1.896613e+08   December

# %%
plt.figure(figsize=(15,8))
sns.barplot(y = 'Month', x = 'Average Worldwide Gross', palette = 'flare', data = ffinal_df.iloc[0:12])
plt.title('Average Worldwide Gross by Month')
plt.xlabel('Average Worldwide Gross')
plt.ylabel('Month')
sns.set_style("ticks")
sns.despine()
